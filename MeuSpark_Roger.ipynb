# %% [markdown]
# <a href="https://colab.research.google.com/github/0megaAD/Spark/blob/main/MeuSpark_Roger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
spark = SparkSession.builder.appName("MeuSpark-R").getOrCreate()

# %%
data = [("Mikhail", 15), ("Zaky", 13), ("Zoya", 8)]
schema = StructType([
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True)
])

# %%
df = spark.createDataFrame(data, schema=schema)

# %%
df.createOrReplaceTempView("pessoas")

# %%
result = spark.sql("SELECT * FROM pessoas WHERE age > 10")
result.show()
# Out:
# +-------+---+
# |   name|age|
# +-------+---+
# |Mikhail| 15|
# |   Zaky| 13|
# +-------+---+

# %%
df = spark.read.csv("???.csv", header=True, inferSchema=True)
